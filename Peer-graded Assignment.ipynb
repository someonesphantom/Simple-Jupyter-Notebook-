# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Venkat__
# <br/>
# Student

# %% [markdown]
# <i>I am interested in data science because i am curious what we can achieve by analysing all the data we have.</i>

# %% [markdown]
# ### Simple Multiplication

# %%
print(2*2)
# Out:
# 4

# %% [markdown]
# Some things which can be done are:
# ***
#
# * writing a code itself in markdown:
#     ```
#         x = 8
#         y = 9
#         z = x+y
#         pirnt(z)
#     ```
# * ~Even this~
